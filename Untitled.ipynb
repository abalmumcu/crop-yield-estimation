# %%
from utils.dataloaders import datasetloader
from utils.plot import plt_corr,plot_index

from sklearn.metrics import mean_squared_error 
from sklearn.model_selection import train_test_split , cross_val_score
import xgboost as xgb

import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
dataset_path = "/Users/alperbalmumcu/Github/master/dataset/"
loader = datasetloader(dataset_path)

datasets = loader.load_all_pickle_dataset()
dataset_dict = loader.get_as_dict(datasets[0])
print(dataset_dict)
# Out:
# {'alabama': ['baldwin', 'calhoun', 'cherokee', 'coffee', 'covington', 'dale', 'dallas', 'elmore', 'escambia', 'geneva', 'henry', 'houston', 'lauderdale', 'lawrence', 'limestone', 'madison', 'mobile', 'monroe', 'shelby'], 'arizona': ['graham', 'maricopa', 'pinal', 'yuma'], 'arkansas': ['ashley', 'chicot', 'clay', 'craighead', 'crittenden', 'desha', 'drew', 'jefferson', 'lee', 'lincoln', 'mississippi', 'phillips', 'poinsett'], 'california': ['kings', 'merced', 'tulare'], 'georgia': ['appling', 'atkinson', 'baker', 'ben hill', 'berrien', 'bleckley', 'brooks', 'bulloch', 'burke', 'calhoun', 'candler', 'coffee', 'colquitt', 'cook', 'crisp', 'decatur', 'dodge', 'dooly', 'early', 'emanuel', 'grady', 'irwin', 'jeff davis', 'jefferson', 'jenkins', 'laurens', 'miller', 'mitchell', 'pierce', 'pulaski', 'randolph', 'screven', 'seminole', 'sumter', 'tattnall', 'terrell', 'thomas', 'tift', 'turner', 'webster', 'wilcox', 'worth'], 'kansas': ['pratt', 'sumner'], 'louisiana': ['catahoula', 'east carroll', 'franklin', 'madison', 'rapides', 'richland', 'tensas'], 'mississippi': ['attala', 'bolivar', 'calhoun', 'carroll', 'coahoma', 'hinds', 'holmes', 'humphreys', 'leflore', 'lowndes', 'madison', 'montgomery', 'noxubee', 'panola', 'quitman', 'sunflower', 'tallahatchie', 'tunica', 'washington', 'webster', 'yazoo'], 'new mexico': ['dona ana', 'lea'], 'north carolina': ['beaufort', 'bertie', 'chowan', 'edgecombe', 'gates', 'greene', 'halifax', 'harnett', 'hertford', 'johnston', 'jones', 'lenoir', 'martin', 'northampton', 'perquimans', 'pitt', 'robeson', 'sampson', 'wilson'], 'oklahoma': ['beckham', 'caddo', 'comanche', 'cotton', 'custer', 'greer', 'harmon', 'jackson', 'kiowa', 'tillman', 'washita'], 'south carolina': ['bamberg', 'barnwell', 'calhoun', 'clarendon', 'darlington', 'dillon', 'dorchester', 'florence', 'hampton', 'horry', 'lee', 'marlboro', 'orangeburg', 'williamsburg'], 'tennessee': ['carroll', 'chester', 'crockett', 'dyer', 'fayette', 'gibson', 'hardeman', 'haywood', 'lauderdale', 'madison'], 'texas': ['bailey', 'bee', 'bell', 'briscoe', 'burleson', 'caldwell', 'calhoun', 'cameron', 'carson', 'castro', 'childress', 'cochran', 'collingsworth', 'concho', 'crosby', 'dawson', 'deaf smith', 'dickens', 'donley', 'ellis', 'floyd', 'fort bend', 'gaines', 'garza', 'glasscock', 'gray', 'hale', 'hall', 'hansford', 'hardeman', 'hartley', 'haskell', 'hill', 'hockley', 'jackson', 'jim wells', 'jones', 'knox', 'lamb', 'lubbock', 'lynn', 'martin', 'matagorda', 'mcculloch', 'mclennan', 'medina', 'milam', 'mitchell', 'moore', 'navarro', 'nolan', 'nueces', 'ochiltree', 'parmer', 'reagan', 'refugio', 'robertson', 'runnels', 'san patricio', 'swisher', 'terry', 'tom green', 'uvalde', 'wharton', 'wilbarger', 'willacy', 'williamson', 'yoakum']}

# %%
full_df = loader.combine_datasets(datasets,dataset_dict,total_dataset_number=5)

# %%
static_fatures = ["Sand", "Silt", "Clay",
                "Bulk density",
                "Coarse fragments",
                "Total Nitrogen", "pH", 
                "CEC", "SOC", "OCD", "OCS"]

# %%
full_df
# Out:
#           index       evi       lai       fpar       lst_day     lst_nigth  \
# 0    2017-01-01  0.046749  6.570058  43.596748           NaN           NaN
# 1    2017-01-02  0.037707       NaN        NaN           NaN           NaN
# 2    2017-01-03  0.265356       NaN        NaN           NaN           NaN
# 3    2017-01-04  0.279653       NaN        NaN           NaN           NaN
# 4    2017-01-05  0.300822  7.823569  49.621422  14489.019405  13990.560826
# ..          ...       ...       ...        ...           ...           ...
# 361  2020-12-27  0.142920       NaN        NaN  14666.472993  13596.865610
# 362  2020-12-28  0.116510       NaN        NaN  14375.948133  13588.812967
# 363  2020-12-29  0.135226       NaN        NaN  14717.750262  13805.067129
# 364  2020-12-30  0.116936  1.744410  15.325557           NaN           NaN
# 365  2020-12-31  0.080345       NaN        NaN           NaN           NaN
#
#              dayl       prcp        srad       tmax  ...        sf_3  \
# 0    36227.984403  21.909429  194.402769  23.910508  ...  241.478909
# 1    36255.991905  89.208001  133.496931  23.695703  ...  241.478909
# 2    36286.300496   0.000000  242.823973  22.118438  ...  241.478909
# 3    36318.887962   0.000000  230.673772  17.071416  ...  241.478909
# 4    36353.733145   5.064471  265.769352  17.339236  ...  241.478909
# ..            ...        ...         ...        ...  ...         ...
# 361  35367.481312   0.000000  329.167632  20.409933  ...  145.947609
# 362  35388.250399   0.000000  219.040536  12.094108  ...  145.947609
# 363  35411.656263   0.000000  299.196623  20.264741  ...  145.947609
# 364  35437.681620   0.000000  131.497568   5.969028  ...  145.947609
# 365           NaN        NaN         NaN        NaN  ...  145.947609
#
#            sf_4        sf_5       sf_6         sf_7        sf_8       sf_9  \
# 0    218.091482   92.958904  52.015565  2617.824646  145.563338   4.973312
# 1    218.091482   92.958904  52.015565  2617.824646  145.563338   4.973312
# 2    218.091482   92.958904  52.015565  2617.824646  145.563338   4.973312
# 3    218.091482   92.958904  52.015565  2617.824646  145.563338   4.973312
# 4    218.091482   92.958904  52.015565  2617.824646  145.563338   4.973312
# ..          ...         ...        ...          ...         ...        ...
# 361  185.418075  109.261333  77.933179   556.218997   56.119027  33.153465
# 362  185.418075  109.261333  77.933179   556.218997   56.119027  33.153465
# 363  185.418075  109.261333  77.933179   556.218997   56.119027  33.153465
# 364  185.418075  109.261333  77.933179   556.218997   56.119027  33.153465
# 365  185.418075  109.261333  77.933179   556.218997   56.119027  33.153465
#
#           sf_10      sf_11  yield
# 0    131.016430  38.137413  906.0
# 1    131.016430  38.137413  906.0
# 2    131.016430  38.137413  906.0
# 3    131.016430  38.137413  906.0
# 4    131.016430  38.137413  906.0
# ..          ...        ...    ...
# 361   92.948824  21.344069  410.0
# 362   92.948824  21.344069  410.0
# 363   92.948824  21.344069  410.0
# 364   92.948824  21.344069  410.0
# 365   92.948824  21.344069  410.0
#
# [421806 rows x 28 columns]

# %%
full_df.rename(columns={'index':'Date'}, inplace=True)
full_df_NAN = full_df.replace(np.nan,'NAN',regex=True)
full_df_NAN['Date'] =  pd.to_datetime(full_df_NAN['Date'], infer_datetime_format=True)

feature1_col = 'evi'
feature2_col = 'lai'
feature3_col = 'ssm'
#df = full_df_NAN.copy()
#df_filtered = df[(df[feature1_col] != 'NAN') & (df[feature2_col] != 'NAN') & (df[feature3_col] != 'NAN')]

# %%
full_df_NAN
# Out:
#           Date       evi       lai       fpar       lst_day     lst_nigth  \
# 0   2017-01-01  0.046749  6.570058  43.596748           NAN           NAN
# 1   2017-01-02  0.037707       NAN        NAN           NAN           NAN
# 2   2017-01-03  0.265356       NAN        NAN           NAN           NAN
# 3   2017-01-04  0.279653       NAN        NAN           NAN           NAN
# 4   2017-01-05  0.300822  7.823569  49.621422  14489.019405  13990.560826
# ..         ...       ...       ...        ...           ...           ...
# 361 2020-12-27   0.14292       NAN        NAN  14666.472993   13596.86561
# 362 2020-12-28   0.11651       NAN        NAN  14375.948133  13588.812967
# 363 2020-12-29  0.135226       NAN        NAN  14717.750262  13805.067129
# 364 2020-12-30  0.116936   1.74441  15.325557           NAN           NAN
# 365 2020-12-31  0.080345       NAN        NAN           NAN           NAN
#
#              dayl       prcp        srad       tmax  ...        sf_3  \
# 0    36227.984403  21.909429  194.402769  23.910508  ...  241.478909
# 1    36255.991905  89.208001  133.496931  23.695703  ...  241.478909
# 2    36286.300496        0.0  242.823973  22.118438  ...  241.478909
# 3    36318.887962        0.0  230.673772  17.071416  ...  241.478909
# 4    36353.733145   5.064471  265.769352  17.339236  ...  241.478909
# ..            ...        ...         ...        ...  ...         ...
# 361  35367.481312        0.0  329.167632  20.409933  ...  145.947609
# 362  35388.250399        0.0  219.040536  12.094108  ...  145.947609
# 363  35411.656263        0.0  299.196623  20.264741  ...  145.947609
# 364   35437.68162        0.0  131.497568   5.969028  ...  145.947609
# 365           NAN        NAN         NAN        NAN  ...  145.947609
#
#            sf_4        sf_5       sf_6         sf_7        sf_8       sf_9  \
# 0    218.091482   92.958904  52.015565  2617.824646  145.563338   4.973312
# 1    218.091482   92.958904  52.015565  2617.824646  145.563338   4.973312
# 2    218.091482   92.958904  52.015565  2617.824646  145.563338   4.973312
# 3    218.091482   92.958904  52.015565  2617.824646  145.563338   4.973312
# 4    218.091482   92.958904  52.015565  2617.824646  145.563338   4.973312
# ..          ...         ...        ...          ...         ...        ...
# 361  185.418075  109.261333  77.933179   556.218997   56.119027  33.153465
# 362  185.418075  109.261333  77.933179   556.218997   56.119027  33.153465
# 363  185.418075  109.261333  77.933179   556.218997   56.119027  33.153465
# 364  185.418075  109.261333  77.933179   556.218997   56.119027  33.153465
# 365  185.418075  109.261333  77.933179   556.218997   56.119027  33.153465
#
#           sf_10      sf_11  yield
# 0    131.016430  38.137413  906.0
# 1    131.016430  38.137413  906.0
# 2    131.016430  38.137413  906.0
# 3    131.016430  38.137413  906.0
# 4    131.016430  38.137413  906.0
# ..          ...        ...    ...
# 361   92.948824  21.344069  410.0
# 362   92.948824  21.344069  410.0
# 363   92.948824  21.344069  410.0
# 364   92.948824  21.344069  410.0
# 365   92.948824  21.344069  410.0
#
# [421806 rows x 28 columns]

# %%
df_filtered.dtypes
# Out:
# Date         datetime64[ns]
# evi                  object
# lai                  object
# fpar                 object
# lst_day              object
# lst_nigth            object
# dayl                 object
# prcp                 object
# srad                 object
# tmax                 object
# tmin                 object
# vp                   object
# ssm                  object
# 164  153.173881  42.690185  983.0
# 176  153.173881  42.690185  983.0
# 188  153.173881  42.690185  983.0
# 200  153.173881  42.690185  983.0
# 212  153.173881  42.690185  983.0
# 224  153.173881  42.690185  983.0
# 236  153.173881  42.690185  983.0
#
# [50 rows x 28 columns]

# %%
df_filtered.Date = pd.to_datetime(df_filtered.Date)
# Out:
# /var/folders/5x/6qn4dr6x2_57w8c6tfg6pqfr0000gn/T/ipykernel_7965/4176300560.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.Date = pd.to_datetime(df_filtered.Date)

# %%
df_filtered.dtypes
# Out:
# Date         datetime64[ns]
# evi                  object
# lai                  object
# fpar                 object
# lst_day              object
# lst_nigth            object
# dayl                 object
# prcp                 object
# srad                 object
# tmax                 object
# tmin                 object
# vp                   object
# ssm                  object
# susm                 object
# state                object
# city                 object
# sf_1                float64
# sf_2                float64
# sf_3                float64
# sf_4                float64
# sf_5                float64
# sf_6                float64
# sf_7                float64
# sf_8                float64
# sf_9                float64
# sf_10               float64
# sf_11               float64
# yield               float64
# dtype: object

# %%
static_fatures = ["Sand", "Silt", "Clay",
                "Bulk density",
                "Coarse fragments",
                "Total Nitrogen", "pH", 
                "CEC", "SOC", "OCD", "OCS"]


blacklist_states = ['kansas', 'new mexico', 'california', 'arizona']

for idx in range(len(blacklist_states)):
    del dataset_dict[blacklist_states[idx]]

# %%
def _dataset():
    
    df_list = []
    yield_list = []
    evi_list = []
    raw_list = []
    i = 0

    for state in dataset_dict.keys():
        for city in dataset_dict[state]:
            for dataset_number in range(5):
                    df_all = datasets[dataset_number][state][city]['dynamic']
                    yield_data = datasets[dataset_number][state][city]['yield']
                    static_data = datasets[dataset_number][state][city]['static']

                    for i, static_feature in enumerate(static_data):
                        df_all[static_fatures[i]] = static_feature.astype(np.float64)
                        
                    df_all['yield'] = yield_data 
                    
                    df_all.index = pd.to_datetime(df_all.index)
                    df_all = df_all.sort_index(ascending=True)

                    df_all = df_all.interpolate()
                    df_monthly = df_all[(df_all.index.month >= 4) & (df_all.index.month <= 9)]


                    window_size = 7  # Length of the moving average filter
                    filter_radius = window_size // 2  # Radius of the filter (number of days before and after the current day)

                    filtered_df = pd.DataFrame()  # DataFrame to store the filtered data

                    # Apply moving average filter to each feature
                    for feature in df_monthly.columns:
                        moving_averages = []
                        for i in range(len(df_monthly)):
                            start_idx = max(i - filter_radius, 0)
                            end_idx = min(i + filter_radius + 1, len(df_monthly))
                            window = df_monthly.iloc[start_idx:end_idx][feature]
                            window_average = round(np.mean(window), 6)
                            moving_averages.append(window_average)

                        filtered_df[feature] = moving_averages

                    filtered_df.set_index(df_monthly.index, inplace=True)

                    df_dayly = filtered_df[(filtered_df.index.day == 15)]


                    df_dayly.index = pd.to_datetime(df_dayly.index, format = '%Y-%m-%d').strftime('%m-%d')

                    for col in range(1,24):
                        df_dayly[df_dayly.columns[col]] = df_dayly[df_dayly.columns[col]].astype('float64')


                    if all(0 <= x <= 1 for x in df_dayly.iloc[:, 0]):
                        df_filtered = df_dayly.select_dtypes(include=['float64', 'int64'])  
                        # Scale the input data

                        raw_list.append(df_filtered)

    df_full = np.stack(raw_list)
                        
    return df_full

# %%
raw_list = _dataset()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 raw_list = _dataset()
#
# Input In [30], in _dataset()
#      50 df_dayly.index = pd.to_datetime(df_dayly.index, format = '%Y-%m-%d').strftime('%m-%d')
#      52 for col in range(1,28):
# ---> 53     df_dayly[df_dayly.columns[col]] = df_dayly[df_dayly.columns[col]].astype('float64')
#      56 if all(0 <= x <= 1 for x in df_dayly.iloc[:, 0]):
#      57     df_filtered = df_dayly.select_dtypes(include=['float64', 'int64'])
#
# File ~/miniforge3/envs/env_tf/lib/python3.8/site-packages/pandas/core/indexes/base.py:5039, in Index.__getitem__(self, key)
#    5036 if is_integer(key) or is_float(key):
#    5037     # GH#44051 exclude bool, which would return a 2d ndarray
#    5038     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5039     return getitem(key)
#    5041 if isinstance(key, slice):
#    5042     # This case is separated from the conditional above to avoid
#    5043     # pessimization com.is_bool_indexer and ndim checks.
#    5044     result = getitem(key)
#
# IndexError: index 25 is out of bounds for axis 0 with size 25

# %%
raw_list.shape

# %%
raw_list
# Out:
# array([[[3.10849000e-01, 1.15464700e+01, 4.51620130e+01, ...,
#          4.97331200e+00, 1.31016430e+02, 3.81374130e+01],
#         [3.28404000e-01, 1.25072460e+01, 4.48116900e+01, ...,
#          4.97331200e+00, 1.31016430e+02, 3.81374130e+01],
#         [1.86835000e-01, 1.21368000e+01, 4.45645380e+01, ...,
#          4.97331200e+00, 1.31016430e+02, 3.81374130e+01],
#         [3.37602000e-01, 1.15879490e+01, 4.06949870e+01, ...,
#          4.97331200e+00, 1.31016430e+02, 3.81374130e+01],
#         [4.29020000e-01, 2.31797140e+01, 6.61861810e+01, ...,
#          4.97331200e+00, 1.31016430e+02, 3.81374130e+01],
#         [4.75267000e-01, 2.02469530e+01, 6.31338760e+01, ...,
#          4.97331200e+00, 1.31016430e+02, 3.81374130e+01]],
#
#        [[3.49247000e-01, 1.47555260e+01, 5.35320250e+01, ...,
#          4.96006100e+00, 1.30646958e+02, 3.75600700e+01],
#         [3.41795000e-01, 1.32098150e+01, 4.68065920e+01, ...,
#          4.96006100e+00, 1.30646958e+02, 3.75600700e+01],
#         [2.62329000e-01, 1.10995790e+01, 4.10101140e+01, ...,
#          4.96006100e+00, 1.30646958e+02, 3.75600700e+01],
#         [4.21566000e-01, 1.54085490e+01, 5.19977420e+01, ...,
#          4.96006100e+00, 1.30646958e+02, 3.75600700e+01],
#         [3.86192000e-01, 1.38341960e+01, 4.61112160e+01, ...,
#          4.96006100e+00, 1.30646958e+02, 3.75600700e+01],
#         [4.32731000e-01, 2.32083630e+01, 6.93612250e+01, ...,
#          4.96006100e+00, 1.30646958e+02, 3.75600700e+01]],
#
#        [[3.24456000e-01, 1.43145960e+01, 5.19507700e+01, ...,
#          5.13108100e+00, 1.30764764e+02, 3.80654810e+01],
#         [3.67986000e-01, 1.43714230e+01, 4.96883370e+01, ...,
#          5.13108100e+00, 1.30764764e+02, 3.80654810e+01],
#         [2.81418000e-01, 1.37753970e+01, 4.72081310e+01, ...,
#          5.13108100e+00, 1.30764764e+02, 3.80654810e+01],
#         [3.57299000e-01, 1.89808380e+01, 5.78554400e+01, ...,
#          5.13108100e+00, 1.30764764e+02, 3.80654810e+01],
#         [5.12034000e-01, 2.01095740e+01, 5.71202320e+01, ...,
#          5.13108100e+00, 1.30764764e+02, 3.80654810e+01],
#         [4.65171000e-01, 2.05968550e+01, 6.44808620e+01, ...,
#          5.13108100e+00, 1.30764764e+02, 3.80654810e+01]],
#
#        ...,
#
#        [[1.51296000e-01, 4.01848900e+00, 2.16786390e+01, ...,
#          3.35808270e+01, 9.28668790e+01, 2.13425710e+01],
#         [1.47158000e-01, 3.35644800e+00, 1.78006900e+01, ...,
#          3.35808270e+01, 9.28668790e+01, 2.13425710e+01],
#         [1.52701000e-01, 3.35274100e+00, 1.80798830e+01, ...,
#          3.35808270e+01, 9.28668790e+01, 2.13425710e+01],
#         [1.90090000e-01, 4.56254500e+00, 2.33018900e+01, ...,
#          3.35808270e+01, 9.28668790e+01, 2.13425710e+01],
#         [2.66653000e-01, 6.78094900e+00, 3.23658110e+01, ...,
#          3.35808270e+01, 9.28668790e+01, 2.13425710e+01],
#         [2.74173000e-01, 6.47055500e+00, 3.20895210e+01, ...,
#          3.35808270e+01, 9.28668790e+01, 2.13425710e+01]],
#
#        [[9.98000000e-02, 2.62238000e+00, 1.48986380e+01, ...,
#          3.30698460e+01, 9.27634890e+01, 2.12786540e+01],
#         [1.32952000e-01, 2.94420500e+00, 1.62801590e+01, ...,
#          3.30698460e+01, 9.27634890e+01, 2.12786540e+01],
#         [1.60661000e-01, 3.34319800e+00, 1.81626880e+01, ...,
#          3.30698460e+01, 9.27634890e+01, 2.12786540e+01],
#         [2.40404000e-01, 5.95692000e+00, 2.84617900e+01, ...,
#          3.30698460e+01, 9.27634890e+01, 2.12786540e+01],
#         [2.67657000e-01, 7.20236800e+00, 3.30313850e+01, ...,
#          3.30698460e+01, 9.27634890e+01, 2.12786540e+01],
#         [3.47053000e-01, 8.76972300e+00, 4.06999680e+01, ...,
#          3.30698460e+01, 9.27634890e+01, 2.12786540e+01]],
#
#        [[1.75767000e-01, 4.47602700e+00, 2.36454420e+01, ...,
#          3.31534650e+01, 9.29488240e+01, 2.13440690e+01],
#         [1.47366000e-01, 3.00966700e+00, 1.64583020e+01, ...,
#          3.31534650e+01, 9.29488240e+01, 2.13440690e+01],
#         [1.38030000e-01, 2.77341300e+00, 1.54136570e+01, ...,
#          3.31534650e+01, 9.29488240e+01, 2.13440690e+01],
#         [1.58512000e-01, 3.18409700e+00, 1.72617050e+01, ...,
#          3.31534650e+01, 9.29488240e+01, 2.13440690e+01],
#         [1.55171000e-01, 4.57735500e+00, 2.40068620e+01, ...,
#          3.31534650e+01, 9.29488240e+01, 2.13440690e+01],
#         [1.68626000e-01, 3.94411700e+00, 2.25328160e+01, ...,
#          3.31534650e+01, 9.29488240e+01, 2.13440690e+01]]])

# %%
import glob
import pandas as pd
from multiprocessing import Pool

static_fatures = ["Sand", "Silt", "Clay",
                              "Bulk density",
                              "Coarse fragments",
                              "Total Nitrogen", "pH", 
                              "CEC", "SOC", "OCD", "OCS"]

def process_data(state, city, dataset_number, datasets, selected_day):

    df_all = datasets[dataset_number][state][city]['dynamic']
    yield_data = datasets[dataset_number][state][city]['yield']
    static_data = datasets[dataset_number][state][city]['static']

    for i, static_feature in enumerate(static_data):
        df_all[static_fatures[i]] = static_feature.astype(np.float64)

    df_all.index = pd.to_datetime(df_all.index)
    df_all = df_all.sort_index(ascending=True)

    df_all = df_all.interpolate()
    df_monthly = df_all[(df_all.index.month >= 4) & (df_all.index.month <= 9)]


    window_size = 7  # Length of the moving average filter
    filter_radius = window_size // 2  # Radius of the filter (number of days before and after the current day)

    filtered_df = pd.DataFrame()  # DataFrame to store the filtered data

    # Apply moving average filter to each feature
    for feature in df_monthly.columns:
        moving_averages = []
        for i in range(len(df_monthly)):
            start_idx = max(i - filter_radius, 0)
            end_idx = min(i + filter_radius + 1, len(df_monthly))
            window = df_monthly.iloc[start_idx:end_idx][feature]
            window_average = round(np.mean(window), 6)
            moving_averages.append(window_average)

        filtered_df[feature] = moving_averages

    filtered_df.set_index(df_monthly.index, inplace=True)

    df_dayly = filtered_df[(filtered_df.index.day == selected_day)]


    df_dayly.index = pd.to_datetime(df_dayly.index, format = '%Y-%m-%d').strftime('%m-%d')

    for col in range(1,24):
        df_dayly[df_dayly.columns[col]] = df_dayly[df_dayly.columns[col]].astype('float64')


    if all(0 <= x <= 1 for x in df_dayly.iloc[:, 0]):
        df_filtered = df_dayly.select_dtypes(include=['float64', 'int64'])  
        # Scale the input data
        return df_filtered


class DatasetLoader:
    def __init__(self,dataset_folder_path):
        self.dataset_folder = dataset_folder_path
        self.datasets = []
        self.state_names = {}
        self.df_list = []
        self.static_fatures = ["Sand", "Silt", "Clay",
                              "Bulk density",
                              "Coarse fragments",
                              "Total Nitrogen", "pH", 
                              "CEC", "SOC", "OCD", "OCS"]

        
    def load_all_pickle_dataset(self):
        all_dataset = glob.glob(self.dataset_folder+'/*.pkl')
        for itm in all_dataset:
            file_ = open(itm,'rb')
            object_file = pd.read_pickle(file_)
            self.datasets.append(object_file)
        return self.datasets

    def get_as_dict(self,dataset):
        states = []
        for key, _ in dataset.items():
            states.append(key)
        cities = []
        for state in states:
            tmp = []
            for key, _ in dataset[state].items():
                tmp.append(key)
            cities.append(tmp)
        for idx in range(len(states)):
            self.state_names[states[idx]] = cities[idx]
        return self.state_names


    def combine_datasets(self, datasets, dataset_dict, selected_day):
        # Use multiprocessing to parallelize the processing
        num_processes = min(8, len(dataset_dict))  # Adjust the number of processes as needed
        with Pool(num_processes) as pool:
            results = []
            for state in dataset_dict.keys():
                for city in dataset_dict[state]:
                    for dataset_number in range(5):
                        results.append(pool.apply_async(process_data, (state, city, dataset_number, datasets, selected_day)))

            processed_data = [result.get() for result in results]

        # Combine the processed DataFrames
        combined_data = np.stack([data.values for data in processed_data if data is not None])
        return combined_data

# %%
dataset_path = "/Users/alperbalmumcu/Github/master/dataset/"
loader = DatasetLoader(dataset_path)

datasets = loader.load_all_pickle_dataset()
dataset_dict = loader.get_as_dict(datasets[0])
print(dataset_dict)

blacklist_states = ['kansas', 'new mexico', 'california', 'arizona']

for idx in range(len(blacklist_states)):
    del dataset_dict[blacklist_states[idx]]
# Out:
# {'alabama': ['baldwin', 'calhoun', 'cherokee', 'coffee', 'covington', 'dale', 'dallas', 'elmore', 'escambia', 'geneva', 'henry', 'houston', 'lauderdale', 'lawrence', 'limestone', 'madison', 'mobile', 'monroe', 'shelby'], 'arizona': ['graham', 'maricopa', 'pinal', 'yuma'], 'arkansas': ['ashley', 'chicot', 'clay', 'craighead', 'crittenden', 'desha', 'drew', 'jefferson', 'lee', 'lincoln', 'mississippi', 'phillips', 'poinsett'], 'california': ['kings', 'merced', 'tulare'], 'georgia': ['appling', 'atkinson', 'baker', 'ben hill', 'berrien', 'bleckley', 'brooks', 'bulloch', 'burke', 'calhoun', 'candler', 'coffee', 'colquitt', 'cook', 'crisp', 'decatur', 'dodge', 'dooly', 'early', 'emanuel', 'grady', 'irwin', 'jeff davis', 'jefferson', 'jenkins', 'laurens', 'miller', 'mitchell', 'pierce', 'pulaski', 'randolph', 'screven', 'seminole', 'sumter', 'tattnall', 'terrell', 'thomas', 'tift', 'turner', 'webster', 'wilcox', 'worth'], 'kansas': ['pratt', 'sumner'], 'louisiana': ['catahoula', 'east carroll', 'franklin', 'madison', 'rapides', 'richland', 'tensas'], 'mississippi': ['attala', 'bolivar', 'calhoun', 'carroll', 'coahoma', 'hinds', 'holmes', 'humphreys', 'leflore', 'lowndes', 'madison', 'montgomery', 'noxubee', 'panola', 'quitman', 'sunflower', 'tallahatchie', 'tunica', 'washington', 'webster', 'yazoo'], 'new mexico': ['dona ana', 'lea'], 'north carolina': ['beaufort', 'bertie', 'chowan', 'edgecombe', 'gates', 'greene', 'halifax', 'harnett', 'hertford', 'johnston', 'jones', 'lenoir', 'martin', 'northampton', 'perquimans', 'pitt', 'robeson', 'sampson', 'wilson'], 'oklahoma': ['beckham', 'caddo', 'comanche', 'cotton', 'custer', 'greer', 'harmon', 'jackson', 'kiowa', 'tillman', 'washita'], 'south carolina': ['bamberg', 'barnwell', 'calhoun', 'clarendon', 'darlington', 'dillon', 'dorchester', 'florence', 'hampton', 'horry', 'lee', 'marlboro', 'orangeburg', 'williamsburg'], 'tennessee': ['carroll', 'chester', 'crockett', 'dyer', 'fayette', 'gibson', 'hardeman', 'haywood', 'lauderdale', 'madison'], 'texas': ['bailey', 'bee', 'bell', 'briscoe', 'burleson', 'caldwell', 'calhoun', 'cameron', 'carson', 'castro', 'childress', 'cochran', 'collingsworth', 'concho', 'crosby', 'dawson', 'deaf smith', 'dickens', 'donley', 'ellis', 'floyd', 'fort bend', 'gaines', 'garza', 'glasscock', 'gray', 'hale', 'hall', 'hansford', 'hardeman', 'hartley', 'haskell', 'hill', 'hockley', 'jackson', 'jim wells', 'jones', 'knox', 'lamb', 'lubbock', 'lynn', 'martin', 'matagorda', 'mcculloch', 'mclennan', 'medina', 'milam', 'mitchell', 'moore', 'navarro', 'nolan', 'nueces', 'ochiltree', 'parmer', 'reagan', 'refugio', 'robertson', 'runnels', 'san patricio', 'swisher', 'terry', 'tom green', 'uvalde', 'wharton', 'wilbarger', 'willacy', 'williamson', 'yoakum']}

# %%
dfs_array_15 = loader.combine_datasets(datasets,dataset_dict,selected_day=15)
